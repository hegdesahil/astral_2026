# %% [markdown]
# # using phyphox outputs
# `phyphox` outputs light curve data in the same type of file that we saw yesterday (`.csv`). Load the data into your account by dragging and dropping the file into the sidebar.
#
# Now that the data is here, read in the values from the file to the code in the cell below. We are specifically interested in the time (first column) and luminance (third column). *(hint: we did this yesterday! also, you will need to add the `skiprows=` and `usecols=` arguments to your `np.loadtxt()` function!)*

# %% [markdown]
# Now, make a graph of the luminance (y-axis) vs. time (x-axis) in the cell below. Make sure to label your axes!

# %% [markdown]
# Finally, as discussed, we'll be working in terms of *normalized* brightness, rather than just raw brightness. Normalize your light curve by the *maximum* value using the `np.max()` function.
